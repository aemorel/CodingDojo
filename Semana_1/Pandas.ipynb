# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Sample Media Spend Data.csv')
print(df.shape)
df.head()
# Out:
# (3051, 10)
#   Division Calendar_Week  Paid_Views  Organic_Views  Google_Impressions  \
# 0        A      1/6/2018         392            422                 408
# 1        A     1/13/2018         787            904                 110
# 2        A     1/20/2018          81            970                 742
# 3        A     1/27/2018          25            575                  65
# 4        A      2/3/2018         565            284                 295
#
#    Email_Impressions  Facebook_Impressions  Affiliate_Impressions  \
# 0        349895.0107                 73580                  12072
# 1        506270.2176                 11804                   9499
# 2        430042.1538                 52232                  17048
# 3        417745.6658                 78640                  10207
# 4        408505.8012                 40561                   5834
#
#    Overall_Views  Sales
# 0            682  59417
# 1            853  56806
# 2            759  48715
# ...

# %%
import pandas as pd
# Cargar el archivo CSV
file_path = 'C:/Users/Andy/Documents/CodingDojo/Clase_2/Sample Media Spend Data.csv'
data = pd.read_csv(file_path)

# %%
from IPython.display import display

# Ordenar el dataset de mayor a menor por 'Paid_Views'
data_sorted = data.sort_values(by='Paid_Views', ascending=False)

# Mostrar el dataset ordenado como tabla
print("Dataset ordenado por 'Paid_Views' de mayor a menor:")
display(data_sorted.head(10))  # Muestra las primeras 10 filas como tabla
# Out:
# Dataset ordenado por 'Paid_Views' de mayor a menor:
#      Division Calendar_Week  Paid_Views  Organic_Views  Google_Impressions  \
# 187         B    2019-06-08      518190         118035             4258513
# 2447        V    2019-06-08      361081          85635             1913726
# 195         B    2019-08-03      321082         243245             2300864
# 188         B    2019-06-15      320747         118357             3169725
# 2455        V    2019-08-03      258535         178550             1035486
# 203         B    2019-09-28      252545          97645             4773201
# 2448        V    2019-06-15      237467          89611             1559180
# 526         E    2019-06-08      210475          55872             2204860
# 1656        O    2019-06-08      200144          42011             2166105
# 217         B    2020-01-04      195738         120869             2542278
#
#       Email_Impressions  Facebook_Impressions  Affiliate_Impressions  \
# ...
